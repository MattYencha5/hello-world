# %% [markdown]
# # Analysis Spring 2026

# %% [markdown]
# #### This is a test

# %% [markdown]
# Playing around with commits

# %%
import pandas as pd

# %%
data = pd.read_csv("historicalcpi.csv")

# %%
data
# Out:
#      Consumer Price Index item  Year  Percent change
# 0                     All food  1974            14.3
# 1                     All food  1975             8.5
# 2                     All food  1976             3.0
# 3                     All food  1977             6.3
# 4                     All food  1978             9.9
# ...                        ...   ...             ...
# 1117               Other foods  2020             3.1
# 1118               Other foods  2021             2.2
# 1119               Other foods  2022            12.7
# 1120               Other foods  2023             6.6
# 1121               Other foods  2024             0.6
#
# [1122 rows x 3 columns]

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Consumer Price Index item  Year  Percent change
# 0                     All food  1974            14.3
# 1                     All food  1975             8.5
# 2                     All food  1976             3.0
# 3                     All food  1977             6.3
# 4                     All food  1978             9.9
# ...                        ...   ...             ...
# 1117               Other foods  2020             3.1
# 1118               Other foods  2021             2.2
# 1119               Other foods  2022            12.7
# 1120               Other foods  2023             6.6
# 1121               Other foods  2024             0.6
#
# [1122 rows x 3 columns]>

# %%
data.describe()
# Out:
#               Year  Percent change
# count  1122.000000     1097.000000
# mean   1999.000000        3.828624
# std      14.726165        5.374299
# min    1974.000000      -21.100000
# 25%    1986.000000        1.000000
# 50%    1999.000000        2.900000
# 75%    2012.000000        5.600000
# max    2024.000000       52.400000

# %%
data.groupby(["Year"])["Percent change"].mean().plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='Year'>

# %%
data.first
# Out:
# <bound method NDFrame.first of      Consumer Price Index item  Year  Percent change
# 0                     All food  1974            14.3
# 1                     All food  1975             8.5
# 2                     All food  1976             3.0
# 3                     All food  1977             6.3
# 4                     All food  1978             9.9
# ...                        ...   ...             ...
# 1117               Other foods  2020             3.1
# 1118               Other foods  2021             2.2
# 1119               Other foods  2022            12.7
# 1120               Other foods  2023             6.6
# 1121               Other foods  2024             0.6
#
# [1122 rows x 3 columns]>

# %% [markdown]
# 1. # *Large*
# 2. ## <mark>**Pretty Large**</mark>
# 3. ### <del>***Smaller***</del>
# 4. #### ****Small****
